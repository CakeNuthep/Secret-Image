# %% [markdown]
# <a href="https://colab.research.google.com/github/CakeNuthep/Secret-Image/blob/main/See_scret_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from google.colab import files

# %%
path_image = list(files.upload().keys())[0]
# Out:
#      <input type="file" id="files-afddf8d7-6466-4a82-afd3-5eedc5611a78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afddf8d7-6466-4a82-afd3-5eedc5611a78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving result2.png to result2 (1).png

# %%
image = cv.imread(path_image) 
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1165x1600 at 0x7F9C78332FD0>

# %%
lsb = int('0b00001111',2)

# %%
secret_image = image & lsb
secret_image = secret_image << 4
cv2_imshow(secret_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1165x1600 at 0x7F9C65B2EA90>
